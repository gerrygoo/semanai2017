# %%
import xml.etree.ElementTree as ET

tree = ET.parse('train-tagged.xml')
root = tree.getroot()
# Out:
# <Element 'tweet' at 0x10be9b048>

# %%
for child in root:
    print(str(child.tag) + "; " + str(child.attrib))
        
    for child2 in child:
        print(str(child2.tag) + "; " + str(child2.attrib))
# Out:
# tweet; {'id': '456544889786728451'}
# sentiment; {'aspect': 'Afición', 'polarity': 'P'}
# sentiment; {'aspect': 'Equipo-Real_Madrid', 'polarity': 'P'}
# sentiment; {'aspect': 'Equipo', 'polarity': 'P'}
# tweet; {'id': '456544890004852736'}
# sentiment; {'aspect': 'Jugador-Gareth_Bale', 'polarity': 'P'}
# sentiment; {'aspect': 'Partido', 'polarity': 'NEU'}
# sentiment; {'aspect': 'Equipo-Real_Madrid', 'polarity': 'P'}
# tweet; {'id': '456544890231353345'}
# sentiment; {'aspect': 'Equipo-Real_Madrid', 'polarity': 'P'}
# sentiment; {'aspect': 'Partido', 'polarity': 'NEU'}
# sentiment; {'aspect': 'Partido', 'polarity': 'NEU'}
# tweet; {'id': '456544890336206848'}
# sentiment; {'aspect': 'Equipo-Real_Madrid', 'polarity': 'P'}
# tweet; {'id': '456544890533339136'}
# sentiment; {'aspect': 'Jugador-Gareth_Bale', 'polarity': 'NEU'}
# tweet; {'id': '456544890550099968'}
# sentiment; {'aspect': 'Equipo-Real_Madrid', 'polarity': 'P'}
# ...
